# %% [markdown]
# # **Read Data From JSON File**

# %%
file=open('record1.json','r')
a=file.read()
file.close()

# %%
import json

# %%
rec=json.loads(a)

# %%
rec
# Out:
# {'101': {'Mfg_date': '20-06-21',
#   'category': 'biscuits',
#   'name': 'Bourbonn',
#   'pr': 20,
#   'qn': 20},
#  '102': {'Mfg_date': '18-06-21',
#   'category': 'cold drink',
#   'name': 'pepsi',
#   'pr': 50,
#   'qn': 10},
#  '103': {'Mfg_date': '10-03-21',
#   'category': 'cold drink',
#   'name': 'sprite',
#   'pr': 70,
#   'qn': 30},
#  '104': {'Mfg_date': '20-04-21',
#   'category': 'cake',
#   'name': 'chocolate cake',
#   'pr': 90,
#   'qn': 5},
#  '105': {'Mfg_date': '13-05-21',
#   'category': 'cake',
#   'name': 'pineapple cake',
#   'pr': 110,
#   'qn': 10},
#  '106': {'Mfg_date': '20-06-21',
#   'category': 'biscuits',
#   'name': 'parle-g',
#   'pr': 10,
#   'qn': 6},
#  '107': {'Mfg_date': '20-05-20',
#   'category': 'Smartphone',
#   'name': 'samsung galaxy M12',
#   'pr': 13500,
#   'qn': 30},
#  '108': {'Mfg_date': '22-06-19',
#   'category': 'Smartphone',
#   'name': 'Redmi 9A',
#   'pr': 6000,
#   'qn': 60},
#  '109': {'Mfg_date': '2-06-19',
# ...

# %% [markdown]
# # **Add New Item into Inventory**

# %%
print("WELCOME")
prod_id=input("Enter Product ID")
name=input("Enter name of product")
price=int(input("Enter price of Product"))
quant=int(input("Enter quantity of product"))
cat=input("Enter category of product")
date=input("Enter date of manufacturing of product")

rec[prod_id]={'name':name,'pr':price,'qn':quant,'category':cat,'Mfg_date':date}
# Out:
# WELCOME
# Enter Product ID135
# Enter name of productcup cake
# Enter price of Product60
# Enter quantity of product11
# Enter category of productcake
# Enter date of manufacturing of product20-02-21

# %%
rec
# Out:
# {'101': {'Mfg_date': '20-06-21',
#   'category': 'biscuits',
#   'name': 'Bourbonn',
#   'pr': 20,
#   'qn': 20},
#  '102': {'Mfg_date': '18-06-21',
#   'category': 'cold drink',
#   'name': 'pepsi',
#   'pr': 50,
#   'qn': 10},
#  '103': {'Mfg_date': '10-03-21',
#   'category': 'cold drink',
#   'name': 'sprite',
#   'pr': 70,
#   'qn': 30},
#  '104': {'Mfg_date': '20-04-21',
#   'category': 'cake',
#   'name': 'chocolate cake',
#   'pr': 90,
#   'qn': 5},
#  '105': {'Mfg_date': '13-05-21',
#   'category': 'cake',
#   'name': 'pineapple cake',
#   'pr': 110,
#   'qn': 10},
#  '106': {'Mfg_date': '20-06-21',
#   'category': 'biscuits',
#   'name': 'parle-g',
#   'pr': 10,
#   'qn': 6},
#  '107': {'Mfg_date': '20-05-20',
#   'category': 'Smartphone',
#   'name': 'samsung galaxy M12',
#   'pr': 13500,
#   'qn': 30},
#  '108': {'Mfg_date': '22-06-19',
#   'category': 'Smartphone',
#   'name': 'Redmi 9A',
#   'pr': 6000,
#   'qn': 60},
#  '109': {'Mfg_date': '2-06-19',
# ...

# %% [markdown]
# # **Delete Product**

# %%
prod_id=input("Enter Product ID : ")
name=input("Enter name of product to be deleted : ")
# Out:
# Enter Product ID : 123
# Enter name of product to be deleted : orion choco pie

# %%
if(prod_id in rec):
  del rec[prod_id]
  print("Product deleted successfully ")
else:
  print("SORRY,we don't have that product")
# Out:
# Product deleted successfully

# %%
rec
# Out:
# {'101': {'Mfg_date': '20-06-21',
#   'category': 'biscuits',
#   'name': 'Bourbonn',
#   'pr': 20,
#   'qn': 20},
#  '102': {'Mfg_date': '18-06-21',
#   'category': 'cold drink',
#   'name': 'pepsi',
#   'pr': 50,
#   'qn': 10},
#  '103': {'Mfg_date': '10-03-21',
#   'category': 'cold drink',
#   'name': 'sprite',
#   'pr': 70,
#   'qn': 30},
#  '104': {'Mfg_date': '20-04-21',
#   'category': 'cake',
#   'name': 'chocolate cake',
#   'pr': 90,
#   'qn': 5},
#  '105': {'Mfg_date': '13-05-21',
#   'category': 'cake',
#   'name': 'pineapple cake',
#   'pr': 110,
#   'qn': 10},
#  '106': {'Mfg_date': '20-06-21',
#   'category': 'biscuits',
#   'name': 'parle-g',
#   'pr': 10,
#   'qn': 6},
#  '107': {'Mfg_date': '20-05-20',
#   'category': 'Smartphone',
#   'name': 'samsung galaxy M12',
#   'pr': 13500,
#   'qn': 30},
#  '108': {'Mfg_date': '22-06-19',
#   'category': 'Smartphone',
#   'name': 'Redmi 9A',
#   'pr': 6000,
#   'qn': 60},
#  '109': {'Mfg_date': '2-06-19',
# ...

# %%
js=json.dumps(rec)

# %%
file=open('record1.json','w')
file.write(js)
file.close()

# %%
file=open('record1.json','r')
a=file.read()
file.close()

# %%
rec
# Out:
# {'101': {'Mfg_date': '20-06-21',
#   'category': 'biscuits',
#   'name': 'Bourbonn',
#   'pr': 20,
#   'qn': 20},
#  '102': {'Mfg_date': '18-06-21',
#   'category': 'cold drink',
#   'name': 'pepsi',
#   'pr': 50,
#   'qn': 10},
#  '103': {'Mfg_date': '10-03-21',
#   'category': 'cold drink',
#   'name': 'sprite',
#   'pr': 70,
#   'qn': 30},
#  '104': {'Mfg_date': '20-04-21',
#   'category': 'cake',
#   'name': 'chocolate cake',
#   'pr': 90,
#   'qn': 5},
#  '105': {'Mfg_date': '13-05-21',
#   'category': 'cake',
#   'name': 'pineapple cake',
#   'pr': 110,
#   'qn': 10},
#  '106': {'Mfg_date': '20-06-21',
#   'category': 'biscuits',
#   'name': 'parle-g',
#   'pr': 10,
#   'qn': 6},
#  '107': {'Mfg_date': '20-05-20',
#   'category': 'Smartphone',
#   'name': 'samsung galaxy M12',
#   'pr': 13500,
#   'qn': 30},
#  '108': {'Mfg_date': '22-06-19',
#   'category': 'Smartphone',
#   'name': 'Redmi 9A',
#   'pr': 6000,
#   'qn': 60},
#  '109': {'Mfg_date': '2-06-19',
# ...
